# %%
## Take home exercises

1. Write a program that takes a word as an input and print the number of vowels in the word.
2. Iterate through the following list of animals and print each one in all caps.

  animals=['tiger', 'elephant', 'monkey', 'zebra', 'panther']

3. Write a program that iterates from 1 to 20, printing each number and whether it's odd or even.
4. Write a program to check if a string is a palindrome or not.
5. Write a function *sum_of_integers(a, b)* that takes two integers as input from the user and returns their sum. (optional)

# %%
#EX1
vowels = ['a','e','i','o','u']

word = input("Choose a word: ")

count = 0
for char in word:
    if char in vowels:
        count += 1

print(count)
# Out:
# Choose a word:  surefire
# 4

# %%
#EX2
animals=['tiger', 'elephant', 'monkey', 'zebra', 'panther']

for item in animals:
    print(item.upper())
# Out:
# TIGER
# ELEPHANT
# MONKEY
# ZEBRA
# PANTHER

# %%
#EX3
#Write a program that iterates from 1 to 20, printing each number and whether it's odd or even.

count = 0
for i in range(1,21):
    if i%2 == 0:
        count += 1
print(count)
# Out:
# 10

# %%
#EX4
#4. Write a program to check if a string is a palindrome or not.
phrase = input("Input a phrase to check if it is a palindrome: ")

phrase = phrase.lower()
phrase = list(phrase)

reverse_phrase = phrase[::-1]

print(reverse_phrase == phrase)
# Out:
# Input a phrase to check if it is a palindrome:  racecar
# True

# %%
#EX5
#5. Write a function *sum_of_integers(a, b)* that takes two integers as input from the user and returns their sum. (optional)
int1 = int(input("Pick first int: "))
int2 = int(input("Pick second int: "))

def my_sum(a,b):
    return a+b

my_sum(int1,int2)
# Out:
# Pick first int:  3
# Pick second int:  2
# 5
